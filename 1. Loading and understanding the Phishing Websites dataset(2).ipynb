# %%
# Filter the uneccesary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Fix the random seed
np.random.seed(22)

# %% [markdown]
# Note that you can supply any integer number to `np.random.seed`.

# %%
# Load the dataset
myData = pd.read_csv("F:/Learning Resources Jan 2020/USIU/APT3020-A Knowledge Based Systems/understanding Data/Manning-Phishing-Websites-Detection-master/Phishing.csv",header='infer')
myData.head(5).T
# Out:
#                              0  1  2  3  4
# having_IP_Address           -1  1  1  1  1
# URL_Length                   1  1  0  0  0
# Shortining_Service           1  1  1  1 -1
# having_At_Symbol             1  1  1  1  1
# double_slash_redirecting    -1  1  1  1  1
# Prefix_Suffix               -1 -1 -1 -1 -1
# having_Sub_Domain           -1  0 -1 -1  1
# SSLfinal_State              -1  1 -1 -1  1
# Domain_registeration_length -1 -1 -1  1 -1
# Favicon                      1  1  1  1  1
# port                         1  1  1  1  1
# HTTPS_token                 -1 -1 -1 -1  1
# Request_URL                  1  1  1 -1  1
# URL_of_Anchor               -1  0  0  0  0
# Links_in_tags                1 -1 -1  0  0
# SFH                         -1 -1 -1 -1 -1
# Submitting_to_email         -1  1 -1  1  1
# Abnormal_URL                -1  1 -1  1  1
# Redirect                     0  0  0  0  0
# on_mouseover                 1  1  1  1 -1
# RightClick                   1  1  1  1  1
# popUpWidnow                  1  1  1  1 -1
# Iframe                       1  1  1  1  1
# age_of_domain               -1 -1  1 -1 -1
# DNSRecord                   -1 -1 -1 -1 -1
# web_traffic                 -1  0  1  1  0
# Page_Rank                   -1 -1 -1 -1 -1
# Google_Index                 1  1  1  1  1
# Links_pointing_to_page       1  1  0 -1  1
# Statistical_report          -1  1 -1  1  1
# Result                      -1 -1 -1 -1  1

# %% [markdown]
# While the `head` function returns the first N (the number you supply to it) rows from the DataFrame, the `sample` function randomly samples N (the number you supply to it) rows from the DataFrame. I often find it useful to use the `sample` function.

# %%
myData.sample(10).T
# Out:
#                              8295   10717  1984   6048   2871   9985   2426   \
# having_IP_Address               -1      1      1      1      1     -1      1
# URL_Length                      -1     -1     -1     -1     -1      1     -1
# Shortining_Service               1      1      1     -1      1     -1      1
# having_At_Symbol                -1      1      1      1      1      1      1
# double_slash_redirecting         1      1      1     -1      1     -1      1
# Prefix_Suffix                   -1      1     -1     -1     -1     -1      1
# having_Sub_Domain                1     -1      1      1     -1      1     -1
# SSLfinal_State                   1      1      1      1      1     -1      1
# Domain_registeration_length     -1      1      1      1     -1     -1     -1
# Favicon                          1      1     -1      1      1      1      1
# port                             1      1     -1      1      1      1      1
# HTTPS_token                      1      1      1     -1      1     -1      1
# Request_URL                     -1     -1     -1     -1      1      1      1
# URL_of_Anchor                   -1      0      1      0      0     -1      0
# Links_in_tags                   -1      0     -1      1      0      0     -1
# SFH                             -1      1     -1     -1     -1      0     -1
# Submitting_to_email              1      1     -1      1      1      1      1
# on_mouseover                    -1      1      1      1      1      1      1
# RightClick                       1      1      1      1      1      1      1
# popUpWidnow                     -1      1      1      1      1      1      1
# Iframe                          -1      1      1      1      1      1      1
# age_of_domain                    1      1     -1     -1     -1      1      1
# DNSRecord                        1      1     -1      1     -1      1      1
# web_traffic                      1      1      1     -1      1      0      1
# Page_Rank                        1      1     -1     -1     -1     -1     -1
# Google_Index                    -1      1     -1      1      1      1      1
# Links_pointing_to_page           0      0      1      0      1      0      0
# Statistical_report               1      1      1      1      1      1      1
# Result                           1      1      1     -1      1     -1      1
#
#                              5058   10521  6033
# having_IP_Address                1      1     -1
# URL_Length                      -1      1     -1
# Shortining_Service               1      1      1
# having_At_Symbol                -1     -1      1
# double_slash_redirecting         1      1      1
# Prefix_Suffix                   -1     -1     -1
# having_Sub_Domain               -1      0      0
# SSLfinal_State                  -1      1      1
# Domain_registeration_length      1     -1     -1
# Favicon                          1      1      1
# port                             1      1      1
# HTTPS_token                      1      1      1
# Request_URL                     -1      1      1
# URL_of_Anchor                   -1      0     -1
# Links_in_tags                    0      0     -1
# SFH                             -1     -1     -1
# Submitting_to_email              1      1      1
# Abnormal_URL                     1     -1      1
# Redirect                         0      0      0
# on_mouseover                     1      1      1
# RightClick                       1      1      1
# popUpWidnow                      1      1      1
# Iframe                           1      1      1
# age_of_domain                   -1     -1     -1
# DNSRecord                       -1      1      1
# web_traffic                     -1      1      0
# Page_Rank                       -1     -1      1
# Google_Index                     1      1      1
# Links_pointing_to_page           1      0      0
# Statistical_report               1      1      1
# Result                          -1      1     -1

# %% [markdown]
# `pandas` makes it super easy to investigate the primary facts about your DataFrame. You can quickly count the number of rows and columns of the DataFrame like so -

# %%
# Data dimension
data.shape
# Out:
# (11055, 31)

# %% [markdown]
# The names of the columns in the DataFrame are descriptive. You may also encounter datasets where the column names are anonymized for the sake of user privacy. You can get the names of the columns as easily as -

# %%
# Data columns
data.columns
# Out:
# Index(['having_IP_Address', 'URL_Length', 'Shortining_Service',
#        'having_At_Symbol', 'double_slash_redirecting', 'Prefix_Suffix',
#        'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length',
#        'Favicon', 'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor',
#        'Links_in_tags', 'SFH', 'Submitting_to_email', 'Abnormal_URL',
#        'Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe',
#        'age_of_domain', 'DNSRecord', 'web_traffic', 'Page_Rank',
#        'Google_Index', 'Links_pointing_to_page', 'Statistical_report',
#        'Result'],
#       dtype='object')

# %% [markdown]
# The labels of the dataset are present in the `Result` column. Let's quickly find out how many unique labels/classes are there in the dataset -

# %%
data["Result"].unique()
# Out:
# array([-1,  1], dtype=int64)

# %% [markdown]
# where, -1 denotes "Phishing" and 1 denotes "Normal". As there are only classes present here, it can be termed as a binary classification problem (classification since we want to classify if a website is phishing or not given its features).
